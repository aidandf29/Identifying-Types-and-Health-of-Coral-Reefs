# %%
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications import MobileNetV2, VGG19
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from keras.models import Sequential

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
import numpy as np
import random
import cv2
import os
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install imutils
# Out:
# Requirement already satisfied: imutils in /usr/local/lib/python3.10/dist-packages (0.5.4)

# %%
from imutils import paths

# %%
imagePaths = sorted(list(paths.list_images("/content/drive/MyDrive/Skripsi/data_warna")))

# random shuffle
random.seed(42)
random.shuffle(imagePaths)

data = []
labels = []
image_dims = (224, 224, 3)

for imagePath in imagePaths:
    image = cv2.imread(imagePath)
    image = cv2.resize(image, (image_dims[1], image_dims[0]))
    image = img_to_array(image)
    data.append(image)
    l = label = imagePath.split(os.path.sep)[-2].split("_")
    labels.append(l)

# %%
aug = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest",
)

# %%
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)
print("{} images ({:.2f}MB)".format(len(imagePaths), data.nbytes / (1024 * 1000.0)))
# Out:
# 520 images (611.52MB)

# %%
data = np.array(data)
label = np.array(labels)
print(data.shape)
# Out:
# (520, 224, 224, 3)

# %%
mlb = MultiLabelBinarizer()
labels = mlb.fit_transform(labels)
# total 4 labels
print("class labels:")
for (i, label) in enumerate(mlb.classes_):
    print("{}. {}".format(i + 1, label))
# Out:
# class labels:
# 1. lv1
# 2. lv2
# 3. lv3
# 4. lv4
# 5. lv5
# 6. lv6

# %%
def MobileNetV2_model(learning_rate, input_shape,class_number):
    baseModel = MobileNetV2(weights='imagenet',include_top=False, input_tensor=Input(shape=input_shape))
    for layer in baseModel.layers[:-4]:
        layer.trainable = False

    model = Sequential()
    model.add(baseModel)
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(1024, activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(512, activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(class_number, activation='softmax'))

    return model

# %%
bs = 8
lr = 0.001
size = (224, 224)
shape = (224,224, 3)
epochs = 20
class_number = 6

# %%
model = MobileNetV2_model(lr,shape,class_number)
model.compile(loss= "categorical_crossentropy", metrics=["accuracy"], optimizer="adam")
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
# Check layers no. & name
for i,layer in enumerate(model.layers):
    print(i,layer.name)
# Out:
# 0 mobilenetv2_1.00_224
# 1 average_pooling2d
# 2 flatten
# 3 dense
# 4 dropout
# 5 dense_1
# 6 dropout_1
# 7 dense_2

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  average_pooling2d (AverageP  (None, 3, 3, 1280)       0
#  ooling2D)
#
#  flatten (Flatten)           (None, 11520)             0
#
#  dense (Dense)               (None, 1024)              11797504
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 14,583,366
# Trainable params: 12,738,182
# Non-trainable params: 1,845,184
# _________________________________________________________________

# %%
trainX, testX, trainY, testY = train_test_split(data, labels, test_size=0.20)

# %%
print("[INFO] training ...")
H = model.fit(aug.flow(trainX, trainY, batch_size=bs),steps_per_epoch=len(trainX) // bs,	validation_data=(testX, testY),	validation_steps=len(testX) // bs,	epochs=epochs)
# Out:
# [INFO] training ...
# Epoch 1/20
# 52/52 [==============================] - 27s 180ms/step - loss: 9.6481 - accuracy: 0.2188 - val_loss: 3.4880 - val_accuracy: 0.3365
# Epoch 2/20
# 52/52 [==============================] - 5s 96ms/step - loss: 3.7237 - accuracy: 0.2404 - val_loss: 1.5065 - val_accuracy: 0.3942
# Epoch 3/20
# 52/52 [==============================] - 7s 129ms/step - loss: 2.3872 - accuracy: 0.2788 - val_loss: 1.7486 - val_accuracy: 0.3269
# Epoch 4/20
# 52/52 [==============================] - 5s 95ms/step - loss: 2.1104 - accuracy: 0.3197 - val_loss: 1.4559 - val_accuracy: 0.3942
# Epoch 5/20
# 52/52 [==============================] - 7s 130ms/step - loss: 1.7259 - accuracy: 0.3918 - val_loss: 1.5470 - val_accuracy: 0.2596
# Epoch 6/20
# 52/52 [==============================] - 5s 99ms/step - loss: 1.6157 - accuracy: 0.3486 - val_loss: 1.6017 - val_accuracy: 0.4038
# Epoch 7/20
# 52/52 [==============================] - 5s 106ms/step - loss: 1.4611 - accuracy: 0.4279 - val_loss: 1.4529 - val_accuracy: 0.4615
# Epoch 8/20
# 52/52 [==============================] - 5s 96ms/step - loss: 1.5484 - accuracy: 0.4327 - val_loss: 1.3300 - val_accuracy: 0.4615
# Epoch 9/20
# 52/52 [==============================] - 7s 127ms/step - loss: 1.4198 - accuracy: 0.4591 - val_loss: 1.3116 - val_accuracy: 0.5096
# Epoch 10/20
# 52/52 [==============================] - 5s 96ms/step - loss: 1.4597 - accuracy: 0.4447 - val_loss: 1.4179 - val_accuracy: 0.4135
# Epoch 11/20
# 52/52 [==============================] - 7s 129ms/step - loss: 1.4742 - accuracy: 0.4760 - val_loss: 1.3157 - val_accuracy: 0.4904
# Epoch 12/20
# 52/52 [==============================] - 5s 97ms/step - loss: 1.2957 - accuracy: 0.5048 - val_loss: 1.4937 - val_accuracy: 0.4231
# Epoch 13/20
# 52/52 [==============================] - 14s 271ms/step - loss: 1.3906 - accuracy: 0.4495 - val_loss: 1.3988 - val_accuracy: 0.4615
# Epoch 14/20
# 52/52 [==============================] - 8s 147ms/step - loss: 1.3038 - accuracy: 0.4976 - val_loss: 1.5062 - val_accuracy: 0.4135
# Epoch 15/20
# 52/52 [==============================] - 6s 118ms/step - loss: 1.3042 - accuracy: 0.5192 - val_loss: 1.6850 - val_accuracy: 0.3750
# Epoch 16/20
# 52/52 [==============================] - 7s 129ms/step - loss: 1.2362 - accuracy: 0.5288 - val_loss: 1.4512 - val_accuracy: 0.4135
# Epoch 17/20
# 52/52 [==============================] - 5s 97ms/step - loss: 1.1311 - accuracy: 0.5673 - val_loss: 1.7997 - val_accuracy: 0.3462
# Epoch 18/20
# 52/52 [==============================] - 5s 101ms/step - loss: 1.2677 - accuracy: 0.5577 - val_loss: 1.5696 - val_accuracy: 0.4615
# Epoch 19/20
# 52/52 [==============================] - 5s 97ms/step - loss: 1.1338 - accuracy: 0.5745 - val_loss: 1.7797 - val_accuracy: 0.4423
# Epoch 20/20
# 52/52 [==============================] - 7s 129ms/step - loss: 1.0687 - accuracy: 0.6034 - val_loss: 1.6275 - val_accuracy: 0.4231

# %%
print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=bs)
y_predict =predIdxs
# for each image in the testing set we need to find the index of the label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)

# show a nicely formatted classification report
print(classification_report(testY.argmax(axis=1), predIdxs,target_names=mlb.classes_))
# Out:
# [INFO] evaluating network...
# 13/13 [==============================] - 1s 14ms/step
#               precision    recall  f1-score   support
#
#          lv1       1.00      0.64      0.78        14
#          lv2       0.33      0.27      0.30        11
#          lv3       0.52      0.48      0.50        29
#          lv4       0.30      0.40      0.34        25
#          lv5       0.37      0.33      0.35        21
#          lv6       0.14      0.25      0.18         4
#
#     accuracy                           0.42       104
#    macro avg       0.44      0.40      0.41       104
# weighted avg       0.47      0.42      0.44       104

# %%
N = epochs
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")

# %%
# Pembuatan Confusion Matrix Display
cmd= metrics.confusion_matrix(testY.argmax(axis=1), np.argmax(y_predict, axis=1))
display_label = ['lv1','lv2','lv3','lv4','lv5','lv6']

cm_lr= ConfusionMatrixDisplay(cmd, display_labels = display_label )
cm_lr.plot(cmap=plt.cm.RdPu)
plt.title("Confusion Matrix Display")

plt.show()

# %%
model.save('/content/drive/MyDrive/Skripsi/Program CNN/MobileNetV2/mobilenetv2_health_model_1.h5')
